# %%
import pandas as pd

df = pd.read_csv("firewall.csv")
blocked = df[df["action"] != "ACCEPT"]
blocked.groupby("src_ip")["dst_port"].value_counts()
# Out:
# dst_port  src_ip
# 0         185.220.101.33    1
# 22        203.0.113.45      5
#           185.220.101.33    1
# 23        193.169.255.78    1
# 161       91.241.19.84      1
# 445       45.155.205.211    3
# 3389      198.51.100.7      2
# Name: count, dtype: int64
